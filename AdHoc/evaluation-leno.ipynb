# %%
import exp_utils

#Folder containing all experiment files
fileFolder = '../ProcessedFiles/'

#Experiment 1 - Simultaneously Learning agents

source1 = fileFolder + 'AdHocTD'
source2 = fileFolder + 'AdHocVisit'
source3 = fileFolder + 'Torrey'
source4 = fileFolder + 'EpisodeSharing'
source5 = fileFolder + 'SARSATile'
source6 = fileFolder + 'Dummy'

name1 = 'AdHocTD'
name2 = 'AdHocVisit'
name3 = 'Torrey'
name4 = 'EpisodeSharing'
name5 = 'NoAdvice'
name6 = 'Random'


#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source1,compact=True)
exp_utils.collect_experiment_data(source2, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source2,compact=True)
exp_utils.collect_experiment_data(source3, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source3,compact=True)
exp_utils.collect_experiment_data(source4, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source4,compact=True)
exp_utils.collect_experiment_data(source5, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source5,compact=True)
exp_utils.collect_experiment_data(source6, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source6,compact=True)

#Intervals for zoomed averages
xMinPerc = 4500
xMaxPerc = 5000
yMinPerc = 64
yMaxPerc = 75

#Intervals for Time for Goal graphs
xMinStep = 3000
xMaxStep = 5000
yMinStep = 95
yMaxStep = 110

xMinStep2 = 0
xMaxStep2 = 1000
yMinStep2 = 30
yMaxStep2 = 110


printCI = True


exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,source6=source6,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,name6=name6,
                    ci=printCI)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,source5=source5,source6=source6,
                     name6=name6,name5=name5,name4=name4, name3=name3,name1=name1, name2=name2, what="__SUMMARY_goaltimes",ci=printCI,
                    xMin = xMinStep, xMax = xMaxStep, yMin = yMinStep, yMax = yMaxStep,nCol=5)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,source5=source5,source6=source6,
                     name6=name6,name5=name5,name4=name4, name3=name3,name1=name1, name2=name2, what="__SUMMARY_goaltimes",ci=printCI,
                    xMin = xMinStep2, xMax = xMaxStep2, yMin = yMinStep2, yMax = yMaxStep2)
exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4=source4,
                     name4 = name4,name3=name3,name1=name1, name2=name2,what="__SUMMARY_budgets",ci=printCI,nCol=2)

exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,source6=source6,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,name6=name6,
                     xMin = xMinPerc, xMax = xMaxPerc, yMin = yMinPerc, yMax = yMaxPerc, ci=False,nCol=5)


#Experiment 2 - Simultaneously Learning agents with Mistake Correcting

source1 = fileFolder + 'AdHocTDAction'
source2 = fileFolder + 'AdHocVisitAction'
source3 = fileFolder + 'TorreyAction'
source4 = fileFolder + 'Torrey'


name1 = 'AdHocTD'
name2 = 'AdHocVisit'
name3 = 'Torrey'
name4 = 'TorreyScenario1'




#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source1,compact=True)
exp_utils.collect_experiment_data(source2, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source2,compact=True)
exp_utils.collect_experiment_data(source3, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source3,compact=True)
exp_utils.collect_experiment_data(source4, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source4,compact=True)
exp_utils.collect_experiment_data(source5, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source5,compact=True)
exp_utils.collect_experiment_data(source6, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source6,compact=True)

#Intervals for zoomed averages
xMinPerc = 4500
xMaxPerc = 5000
yMinPerc = 60
yMaxPerc = 75


printCI = True


exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,
                     name4=name4, name3=name3, name1=name1, name2=name2, 
                    ci=printCI)


exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4=source4,
                     name3=name3,name1=name1, name2=name2,name4=name4,what="__SUMMARY_budgets",ci=printCI)

exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,
                     name4=name4, name3=name3, name1=name1, name2=name2, 
                     xMin = xMinPerc, xMax = xMaxPerc, yMin = yMinPerc, yMax = yMaxPerc, ci=False,nCol=6)

#Experiment 3 - One expert Agent

source1 = fileFolder + 'AdHocTDLoading'
source2 = fileFolder + 'AdHocVisitLoading'
source3 = fileFolder + 'TorreyLoading'
source4 = fileFolder + 'EpisodeSharingLoading'
source5 = fileFolder + 'SARSATileLoading'
source6 = fileFolder + 'SARSATile'

name1 = 'AdHocTD'
name2 = 'AdHocVisit'
name3 = 'Torrey'
name4 = 'EpisodeSharing'
name5 = 'NoAdvice'
name6 = 'Scratch'


#Prepare intermediary files with experiment's summary.
exp_utils.collect_experiment_data(source1, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source1,compact=True)
exp_utils.collect_experiment_data(source2, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source2,compact=True)
exp_utils.collect_experiment_data(source3, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source3,compact=True)
exp_utils.collect_experiment_data(source4, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source4,compact=True)
exp_utils.collect_experiment_data(source5, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source5,compact=True)
exp_utils.collect_experiment_data(source6, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source6,compact=True)

#Intervals for zoomed averages
xMinPerc = 4500
xMaxPerc = 5000
yMinPerc = 64
yMaxPerc = 75


printCI = True


exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,source6=source6,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,name6=name6,
                    ci=printCI)


exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4=source4,
                     name4 = name4,name3=name3,name1=name1, name2=name2,what="__SUMMARY_budgets",ci=printCI)

exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
                     xMin = xMinPerc, xMax = xMaxPerc, yMin = yMinPerc, yMax = yMaxPerc, ci=False,nCol=6)
# Out:
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 49 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 49 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
