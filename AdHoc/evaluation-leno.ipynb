# %%
# %matplotlib inline
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from collections import defaultdict
sns.set(style="darkgrid")

# %%
#from exp_utils import collect_experiment_data, summarize_experiment_data
import exp_utils
#source1 = '/home/ruben/playground/HFO/experiments/EVAL/2016_09_12-14.38.02_SARSA_1_5'

source1 = '/home/leno/HFO/log/AdHocTD'
#source1 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/AdHocTD'
source2 = '/home/leno/HFO/log/AdHocVisit'
#source2 = '/home/leno/HFO/experiments/agentData/FilesWithTrainedAgent/AdHocVisitLoading'
#source2 = '/home/leno/HFO/experiments/results/AdHocVisitAction'
#source5 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/AdHocVisit'
source5 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/AdHocTD'
#source3 = '/home/leno/HFO/log/Torrey'
#source3 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/Torrey'
source3 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/SARSATile'

#source5 = '/home/leno/HFO/experiments/agentData/FilesWithTrainedAgent/SARSATileLoading'
#source4 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/EpisodeSharing'
source4 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/SARSATile'
#source2 = '/home/leno/HFO/log/SARSATile'
source6 = '/home/leno/Dropbox/DO - Felipe Leno da Silva/Artigos/AAMAS2017/Data/Dummy'
name1 = 'AdHocTD'
name5 = 'AdHocORIG'
name3 = 'NoAdvice'
name4 = 'EpisodeSharing'
name2 = 'AdHocVisit'
name6 = 'Dummy'

exp_utils.collect_experiment_data(source1, runs = 50)
exp_utils.summarize_experiment_data(source1)
exp_utils.collect_experiment_data(source2, runs = 50)
exp_utils.summarize_experiment_data(source2)
exp_utils.collect_experiment_data(source3, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source3,compact=True)
exp_utils.collect_experiment_data(source4, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source4,compact=True)
exp_utils.collect_experiment_data(source5, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source5,compact=True)
exp_utils.collect_experiment_data(source6, runs = 50,compact=True)
exp_utils.summarize_experiment_data(source6,compact=True)

xMinPerc = 4000
xMaxPerc = 5000
yMinPerc = 63
yMaxPerc = 75


xMinStep = 3000
xMaxStep = 5000
yMinStep = 95
yMaxStep = 110

printCI = False

#first experiment
torreyDiff = range(5,38)
episodeDiff = range(30,40)
visitDiff = range(70,95).append(range(200,250))
TDDiff = range(70,250)
#exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,
#                     name4=name4, name3=name3, name1=name1, name2=name2, ci=printCI)

#exp_utils.draw_graph(source2=source2, source3=source3,source5=source5,
#                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2,name6=name6, ci=printCI,
                    #xMin = xMinPerc, yMin=yMinPerc, xMax = xMaxPerc, yMax=yMaxPerc
#                    )
#exp_utils.draw_graph( source5=source5,  source3=source3,
#                     name5=name5,name3=name3, name2=name2,what="__SUMMARY_budgets",ci=printCI)

exp_utils.draw_graph(source1=source1, source2=source2, source3=source3,source4 = source4,source5=source5,#source6=source6,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
                    ci=printCI)

exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,source5=source5,source6=source6,
                     name6=name6,name5=name5,name4=name4, name3=name3,name1=name1, name2=name2, what="__SUMMARY_goaltimes",ci=printCI)
exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4=source4,name4=name4,source5=source5,name5=name5,
                     name3=name3,name1=name1, name2=name2,what="__SUMMARY_budgets",ci=printCI)

#exp_utils.draw_graph(source1=source1,  source3=source3,source4 = source4,source5=source5,
#                     name5=name5,name4=name4, name3=name3, name1=name1, name2=name2,name6=name6, ci=printCI, what="__SUMMARY_reward"
                    #significant1 = TDDiff,significant2 = visitDiff,significant3 = torreyDiff,significant4=episodeDiff
#                    )

exp_utils.draw_graph(source1=source1, source2=source2, #source3=source3,source4 = source4,#source5=source5,
                     name4=name4, name3=name3, name1=name1, name2=name2, name5=name5,
                    ci=printCI,xMin = xMinPerc, yMin=yMinPerc, xMax = xMaxPerc, yMax=yMaxPerc)
exp_utils.draw_graph(source1=source1, source2=source2,  source3=source3,source4 = source4,source6=source6,source5=source5,
                    name5=name5,name4=name4, name3=name3,name1=name1, name2=name2,name6=name6, what="__SUMMARY_goaltimes",ci=printCI,
                    xMin = xMinStep, yMin=yMinStep, xMax = xMaxStep, yMax=yMaxStep)
#exp_utils.draw_graph(source1=source1, source2=source2, source3=source3, source4=source4,ci=False)
#exp_utils.draw_graph(source1=source1, source2=source2,source3=source3,source4=source4, what="__SUMMARY_goaltimes",ci=False)
#exp_utils.draw_graph(source1=source1, source2=source2,source3=source3,source4=source4, what="__SUMMARY_budgets",ci=False)
# Out:
# Error 15 - 194 , 251
# Error 18 - 204 , 251
# Error 27 - 208 , 251
# Error 29 - 197 , 251
# Error 42 - 207 , 251
# Error 44 - 208 , 251
# Error 15 - 194 , 251
# Error 18 - 204 , 251
# Error 27 - 208 , 251
# Error 29 - 197 , 251
# Error 42 - 207 , 251
# Error 44 - 208 , 251
# Error 15 - 194 , 251
# Error 18 - 204 , 251
# Error 27 - 208 , 251
# Error 29 - 197 , 251
# Error 42 - 207 , 251
# Error 44 - 208 , 251
# Could use 37 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Error 31 - 236 , 251
# Error 31 - 236 , 251
# Error 31 - 236 , 251
# Could use 23 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
# Could use 50 runs from expected 50
# len(evalUsedBudgets) 753 --> <type 'list'> 0
